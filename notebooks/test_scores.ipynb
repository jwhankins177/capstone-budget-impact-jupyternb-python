# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_excel(r"C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\test_scores\data_ACT-Data-by-District-2012-13.xlsx",header=1)

# %%
df1
# Out:
#                               System  2013 Including Extended Time  \
# 0                              State                        19.048
# 1    ANDERSON SCHOOL DISTRICT                               18.920
# 2    ALCOA CITY SCHOOLS                                     21.595
# 3    BEDFORD COUNTY SCHOOL DISTRICT                         17.984
# 4    BENTON CO BOARD OF EDUCATION                           18.376
# ..                               ...                           ...
# 115  WEAKLEY CO SCH DIST                                    19.462
# 116  WEST CARROLL SPECIAL SCH DIST                          18.197
# 117  WHITE COUNTY SCHOOL DISTRICT                           18.612
# 118  WILLIAMSON CO SCHOOLS                                  23.359
# 119  WILSON CO SCHLS BOE                                    19.898
#
#      2013 Standard Time Only  2012 Standard Time Only
# 0                       19.3                   19.184
# 1                       19.1                   18.932
# 2                       22.2                   21.955
# 3                       18.3                   19.023
# 4                       19.2                   19.358
# ..                       ...                      ...
# 115                     20.1                   20.076
# 116                     18.3                   18.069
# 117                     18.9                   18.369
# 118                     23.7                   23.134
# 119                     20.2                   19.896
#
# [120 rows x 4 columns]

# %% [markdown]
# 2013 ACT

# %%
#df2014 = df4[(df4['District_Name'] == 'Davidson County')]
#df2014 = df2014[['SCHOOL_YEAR', 'K_8_Attendance_Rate_PCT', 'HS_Attendance_Rate_PCT']]
#df2014.rename(columns={'SCHOOL_YEAR' : 'year', 'K_8_Attendance_Rate_PCT' : 'k_8', 'HS_Attendance_Rate_PCT' : '9_12'},inplace=True)

# %%
df2013 = df1[df1['System']=='METRO NASHVILLE-DAVIDSON CO SD ']

# %%
df2013
# Out:
#                              System  2013 Including Extended Time  \
# 77  METRO NASHVILLE-DAVIDSON CO SD                         18.203
#
#     2013 Standard Time Only  2012 Standard Time Only
# 77                     18.3                   18.381

# %% [markdown]
# 2014 ACT

# %%
df2 = pd.read_excel(r"C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\test_scores\data_ACT-Data-by-District-2013-14.xlsx", header=1)

# %%
df2
# Out:
#                               System 2013 Including Extended Time  \
# 0                              State                       19.048
# 1    ANDERSON SCHOOL DISTRICT                               18.92
# 2    ALCOA CITY SCHOOLS                                    21.595
# 3    BEDFORD COUNTY SCHOOL DISTRICT                        17.984
# 4    BENTON CO BOARD OF EDUCATION                          18.376
# ..                               ...                          ...
# 117  WEAKLEY CO SCH DIST                                   19.462
# 118  WEST CARROLL SPECIAL SCH DIST                         18.197
# 119  WHITE COUNTY SCHOOL DISTRICT                          18.612
# 120  WILLIAMSON CO SCHOOLS                                 23.359
# 121  WILSON CO SCHLS BOE                                   19.898
#
#     2013 Standard Time Only 2014 Including Extended Time
# 0                      19.3                       19.259
# 1                      19.1                        19.33
# 2                      22.2                       21.291
# 3                      18.3                       18.446
# 4                      19.2                       18.958
# ..                      ...                          ...
# 117                    20.1                       20.251
# 118                    18.3                       18.773
# 119                    18.9                       18.621
# 120                    23.7                       23.515
# 121                    20.2                       19.735
#
# [122 rows x 4 columns]

# %%
df2014 = df1[df1['System']=='METRO NASHVILLE-DAVIDSON CO SD ']

# %%
df2014
# Out:
#                              System  2013 Including Extended Time  \
# 77  METRO NASHVILLE-DAVIDSON CO SD                         18.203
#
#     2013 Standard Time Only  2012 Standard Time Only
# 77                     18.3                   18.381

# %% [markdown]
# 2015 ACT

# %%
df3 = pd.read_excel(r"C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\test_scores\data_ACT-Data-by-District-2014-15.xlsx", header=1)

# %%
df3
# Out:
#     Unnamed: 0                       Unnamed: 1  2014 Including Extended Time  \
# 0        State                              NaN                        19.259
# 1           10  ANDERSON SCHOOL DISTRICT                               19.330
# 2           12  OAK RIDGE SD                                           23.260
# 3           20  BEDFORD COUNTY SCHOOL DISTRICT                         18.446
# 4           30  BENTON CO BOARD OF EDUCATION                           18.958
# ..         ...                              ...                           ...
# 121        920  WEAKLEY CO SCH DIST                                    20.251
# 122        930  WHITE COUNTY SCHOOL DISTRICT                           18.621
# 123        940  WILLIAMSON CO SCHOOLS                                  23.515
# 124        950  WILSON CO SCHLS BOE                                    19.735
# 125        985  ACHIEVEMENT SCHOOL DISTRICT                               NaN
#
#      2015 Including Extended Time
# 0                            19.4
# 1                            19.9
# 2                            23.1
# 3                            18.4
# 4                            18.4
# ..                            ...
# 121                          19.7
# 122                          18.7
# 123                          23.8
# 124                          20.0
# 125                          14.2
#
# [126 rows x 4 columns]

# %%
df2015 = df3[df3['Unnamed: 1'] == 'METRO NASHVILLE-DAVIDSON CO SD ']

# %%
df2015
# Out:
#    Unnamed: 0                       Unnamed: 1  2014 Including Extended Time  \
# 29        190  METRO NASHVILLE-DAVIDSON CO SD                         18.417
#
#     2015 Including Extended Time
# 29                          18.7

# %%
df2015.drop('Unnamed: 0', axis=1,inplace=True)
# Out:
# c:\Users\jhank\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df2015 = df2015.T

# %%
df2015 = df2015.reset_index()

# %%
df2015.columns = ('year','act_avg')

# %%
df2015.drop([0], inplace=True)

# %%
df2015
# Out:
#                            year act_avg
# 1  2014 Including Extended Time  18.417
# 2  2015 Including Extended Time    18.7

# %% [markdown]
# 2016 ACT

# %%
df4 = pd.read_excel(r"C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\test_scores\data_2015-16_suppressed_district_level_act.xlsx")

# %%
df4
# Out:
#      District                                   District Name      Subgroup  \
# 0          10                                 Anderson County  All Students
# 1          12                                  Oak Ridge City  All Students
# 2          20                                  Bedford County  All Students
# 3          30                                   Benton County  All Students
# 4          40                                  Bledsoe County  All Students
# ..        ...                                             ...           ...
# 124       961                         Alvin C. York Institute  All Students
# 125       963                           Tenn School For Blind  All Students
# 126       964                               Tenn Sch For Deaf  All Students
# 127       970  Department of Children's Services Ed. Division  All Students
# 128       985                     Achievement School District  All Students
#
#      Valid Tests Participation Rate Average English Score Average Math Score  \
# 0            346                 67                  20.3               19.8
# 1            280                 90                  22.9               22.3
# 2            499                 91                    18               18.1
# 3            147                 97                  18.4               18.9
# 4            101                 82                  18.1               18.9
# ..           ...                ...                   ...                ...
# 124          123                 94                  19.7               18.7
# 125            9                  *                     *                  *
# 126            8                  *                     *                  *
# 127           28                 35                  14.3               15.7
# 128          194                 85                  14.3               15.6
#
#     Average Reading Score Average Science Score Average Composite Score  \
# 0                    21.5                  20.9                    20.8
# 1                    23.9                  22.9                    23.1
# 2                      19                  18.9                    18.6
# 3                    19.1                  19.2                    19.1
# 4                    19.5                  19.1                      19
# ..                    ...                   ...                     ...
# 124                  20.1                  19.9                    19.8
# 125                     *                     *                       *
# 126                     *                     *                       *
# 127                  16.3                  15.9                    15.7
# 128                  15.6                  15.7                    15.4
#
#     Percent Scoring 21 or Higher Percent Scoring Below 19
# 0                           50.6                     33.8
# 1                           63.2                       25
# 2                           31.7                     52.1
# 3                           38.1                     47.6
# 4                           34.7                     46.5
# ..                           ...                      ...
# 124                         38.2                     43.9
# 125                            *                        *
# 126                            *                        *
# 127                         10.7                     78.6
# 128                          4.6                     87.6
#
# [129 rows x 12 columns]

# %%
df4['District Name'].unique()
# Out:
# array(['Anderson County', 'Oak Ridge City', 'Bedford County',
#        'Benton County', 'Bledsoe County', 'Blount County', 'Alcoa City',
#        'Maryville City', 'Bradley County', 'Cleveland City',
#        'Campbell County', 'Cannon County', 'Hollow Rock-Bruceton',
#        'Huntingdon Special School District',
#        'McKenzie Special School District',
#        'South Carroll Special School District',
#        'West Carroll Special School District', 'Carter County',
#        'Elizabethton City', 'Cheatham County', 'Chester County',
#        'Claiborne County', 'Clay County', 'Cocke County', 'Coffee County',
#        'Tullahoma City', 'Crockett County', 'Cumberland County',
#        'Davidson County', 'Decatur County', 'DeKalb County',
#        'Dickson County', 'Dyer County', 'Dyersburg City',
#        'Fayette County', 'Fentress County', 'Franklin County',
#        'Humboldt City', 'Milan Special School District',
#        'Trenton Special School District',
#        'Bradford Special School District',
#        'Gibson County Special School District', 'Giles County',
#        'Grainger County', 'Greene County', 'Greeneville City',
#        'Grundy County', 'Hamblen County', 'Hamilton County',
#        'Hancock County', 'Hardeman County', 'Hardin County',
#        'Hawkins County', 'Haywood County', 'Henderson County',
#        'Henry County', 'Hickman County', 'Houston County',
#        'Humphreys County', 'Jackson County', 'Jefferson County',
#        'Johnson County', 'Knox County', 'Lake County',
#        'Lauderdale County', 'Lawrence County', 'Lewis County',
#        'Lincoln County', 'Fayetteville City', 'Loudon County',
#        'Lenoir City', 'McMinn County', 'McNairy County', 'Macon County',
#        'Jackson-Madison County', 'Marion County', 'Richard City',
#        'Marshall County', 'Maury County', 'Meigs County', 'Monroe County',
#        'Montgomery County', 'Moore County', 'Morgan County',
#        'Obion County', 'Union City', 'Overton County', 'Perry County',
#        'Pickett County', 'Polk County', 'Putnam County', 'Rhea County',
#        'Roane County', 'Robertson County', 'Rutherford County',
#        'Scott County', 'Oneida Special School District',
#        'Sequatchie County', 'Sevier County', 'Shelby County (New)',
#        'Arlington City', 'Bartlett City', 'Collierville City',
#        'Germantown City', 'Millington City', 'Smith County',
#        'Stewart County', 'Sullivan County', 'Bristol City',
#        'Kingsport City', 'Sumner County', 'Tipton County',
#        'Trousdale County', 'Unicoi County', 'Union County',
#        'Van Buren County', 'Warren County', 'Washington County',
#        'Johnson City', 'Wayne County', 'Weakley County', 'White County',
#        'Williamson County', 'Wilson County', 'Alvin C. York Institute',
#        'Tenn School For Blind', 'Tenn Sch For Deaf',
#        "Department of Children's Services Ed. Division",
#        'Achievement School District'], dtype=object)

# %%
df2016 = df4[df4['District Name'] == 'Davidson County']

# %%
df2016 = df2016[['Average Composite Score']]

# %%
df2016
# Out:
#    Average Composite Score
# 28                    18.7

# %%
df5 = pd.read_excel(r"C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\test_scores\data_ACT-Data-by-District-2016-17.xlsx")

# %%
df5
# Out:
#      District                District Name  \
# 0          10              Anderson County
# 1          10              Anderson County
# 2          10              Anderson County
# 3          10              Anderson County
# 4          10              Anderson County
# ..        ...                          ...
# 640       985  Achievement School District
# 641       985  Achievement School District
# 642       985  Achievement School District
# 643       985  Achievement School District
# 644       985  Achievement School District
#
#                                  Subgroup  Valid Tests  Participation Rate  \
# 0                            All Students          466                94.0
# 1          Black/Hispanic/Native American           19                95.0
# 2              Economically Disadvantaged          125                91.0
# 3    English Language Learners with T1/T2            0                 NaN
# 4              Students with Disabilities           56                79.0
# ..                                    ...          ...                 ...
# 640                          All Students          435                94.0
# 641        Black/Hispanic/Native American          432                94.0
# 642            Economically Disadvantaged          320                94.0
# 643  English Language Learners with T1/T2           13                93.0
# 644            Students with Disabilities           58                88.0
#
#     Average English Score Average Math Score Average Reading Score  \
# 0                    18.4               18.6                  19.6
# 1                    15.7               17.4                    17
# 2                    15.8               16.9                  17.2
# 3                       *                  *                     *
# 4                    11.6               15.6                  13.6
# ..                    ...                ...                   ...
# 640                  14.2               15.6                  15.6
# 641                  14.2               15.6                  15.5
# 642                  13.9               15.5                  15.4
# 643                  13.7               16.8                  17.2
# 644                  12.3               14.9                  13.7
#
#     Average Science Score Average Composite Score Number Scoring 21 or Higher  \
# 0                    19.2                    19.1                         166
# 1                    17.6                    17.1                           4
# 2                    16.8                    16.8                          24
# 3                       *                       *                           *
# 4                    14.8                    14.1                           1
# ..                    ...                     ...                         ...
# 640                  16.5                    15.6                          27
# 641                  16.5                    15.6                          27
# 642                  16.3                    15.4                          19
# 643                    18                    16.6                           2
# 644                  15.1                    14.1                           2
#
#     Percent Scoring 21 or Higher Number Scoring Below 19  \
# 0                           35.6                     240
# 1                           21.1                      14
# 2                           19.2                      88
# 3                              *                       *
# 4                            1.8                      54
# ..                           ...                     ...
# 640                          6.2                     375
# 641                          6.3                     373
# 642                          5.9                     280
# 643                         15.4                      11
# 644                          3.4                      55
#
#     Percent Scoring Below 19
# 0                       51.5
# 1                       73.7
# 2                       70.4
# 3                          *
# 4                       96.4
# ..                       ...
# 640                     86.2
# 641                     86.3
# 642                     87.5
# 643                     84.6
# 644                     94.8
#
# [645 rows x 14 columns]

# %%
df2017 = df5[df5['District Name'] == 'Davidson County']
df2017
# Out:
#     District    District Name                              Subgroup  \
# 65       190  Davidson County                          All Students
# 66       190  Davidson County        Black/Hispanic/Native American
# 67       190  Davidson County            Economically Disadvantaged
# 68       190  Davidson County  English Language Learners with T1/T2
# 69       190  Davidson County            Students with Disabilities
#
#     Valid Tests  Participation Rate Average English Score Average Math Score  \
# 65         4027                91.0                  18.1               18.4
# 66         2592                90.0                  16.4               17.2
# 67         1849                88.0                  16.1                 17
# 68          444                87.0                  13.6               16.2
# 69          362                85.0                  13.9               15.8
#
#    Average Reading Score Average Science Score Average Composite Score  \
# 65                  19.3                  19.3                      19
# 66                  17.8                    18                    17.5
# 67                  17.4                  17.8                    17.2
# 68                  15.1                  16.5                    15.5
# 69                  15.7                  16.2                    15.5
#
#    Number Scoring 21 or Higher Percent Scoring 21 or Higher  \
# 65                        1278                         31.7
# 66                         537                         20.7
# 67                         329                         17.8
# 68                          29                          6.5
# 69                          39                         10.8
#
#    Number Scoring Below 19 Percent Scoring Below 19
# 65                    2226                     55.3
# 66                    1741                     67.2
# 67                    1302                     70.4
# 68                     381                     85.8
# 69                     305                     84.3

# %%
df2017 = df2017[df2017['Subgroup'] == 'All Students']
df2017
# Out:
#     District    District Name      Subgroup  Valid Tests  Participation Rate  \
# 65       190  Davidson County  All Students         4027                91.0
#
#    Average English Score Average Math Score Average Reading Score  \
# 65                  18.1               18.4                  19.3
#
#    Average Science Score Average Composite Score Number Scoring 21 or Higher  \
# 65                  19.3                      19                        1278
#
#    Percent Scoring 21 or Higher Number Scoring Below 19  \
# 65                         31.7                    2226
#
#    Percent Scoring Below 19
# 65                     55.3

# %%
df2017 = df2017[['Average Composite Score']]
df2017
# Out:
#    Average Composite Score
# 65                      19

# %% [markdown]
# 2018 act

# %%
df6 = pd.read_excel(r"C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\test_scores\2017-18 ACT_district_suppressed.xlsx")

# %%
df6
# Out:
#      District                District Name                        Subgroup  \
# 0          10              Anderson County                    All Students
# 1          10              Anderson County  Black/Hispanic/Native American
# 2          10              Anderson County      Economically Disadvantaged
# 3          10              Anderson County                English Learners
# 4          10              Anderson County      Students with Disabilities
# ..        ...                          ...                             ...
# 640       985  Achievement School District                    All Students
# 641       985  Achievement School District  Black/Hispanic/Native American
# 642       985  Achievement School District      Economically Disadvantaged
# 643       985  Achievement School District                English Learners
# 644       985  Achievement School District      Students with Disabilities
#
#      Valid Tests Participation Rate Average English Score Average Math Score  \
# 0            505                 97                  18.8               18.9
# 1             29                100                  15.9               17.1
# 2            157                 94                  16.3               17.2
# 3              3                  *                     *                  *
# 4             73                 96                  12.9               15.6
# ..           ...                ...                   ...                ...
# 640          395                 83                    14               15.6
# 641          390                 83                    14               15.6
# 642          312                 83                  13.8               15.6
# 643           13                 81                  13.8               15.2
# 644           44                 59                  11.4               14.8
#
#     Average Reading Score Average Science Score Average Composite Score  \
# 0                    19.8                  19.7                    19.4
# 1                    17.4                  17.3                      17
# 2                    17.5                  17.3                    17.2
# 3                       *                     *                       *
# 4                    14.3                    15                    14.6
# ..                    ...                   ...                     ...
# 640                  15.7                  15.9                    15.5
# 641                  15.8                  15.9                    15.5
# 642                  15.6                  15.8                    15.4
# 643                  16.5                  16.9                    15.8
# 644                  13.2                  14.4                    13.7
#
#     Number Scoring 21 or Higher Percent Scoring 21 or Higher  \
# 0                           191                           38
# 1                             4                         14.3
# 2                            37                         23.7
# 3                             *                            *
# 4                             5                          6.9
# ..                          ...                          ...
# 640                          23                          5.8
# 641                          23                          5.9
# 642                          18                          5.8
# 643                           1                          7.7
# 644                          **                           **
#
#     Number Scoring Below 19 Percent Scoring Below 19
# 0                       249                     49.6
# 1                        21                       75
# 2                       105                     67.3
# 3                         *                        *
# 4                        66                     91.7
# ..                      ...                      ...
# 640                     345                     87.6
# 641                     340                     87.4
# 642                     275                     88.4
# 643                      11                     84.6
# 644                      **                       **
#
# [645 rows x 14 columns]

# %%
df2018 = df6[df6['District Name'] == 'Davidson County']
df2018 = df2018[df2018['Subgroup'] == 'All Students']
df2018 = df2018[['Average Composite Score']]

# %%
df2018
# Out:
#     Average Composite Score
# 140                    18.9

# %% [markdown]
# 2019 ACT

# %%
df7 = pd.read_excel(r"C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\test_scores\ACT_district_suppressed_2019.xlsx")

# %%
df7
# Out:
#      District                District Name                        Subgroup  \
# 0          10              Anderson County                    All Students
# 1          10              Anderson County  Black/Hispanic/Native American
# 2          10              Anderson County      Economically Disadvantaged
# 3          10              Anderson County                English Learners
# 4          10              Anderson County      Students with Disabilities
# ..        ...                          ...                             ...
# 590       985  Achievement School District                    All Students
# 591       985  Achievement School District  Black/Hispanic/Native American
# 592       985  Achievement School District      Economically Disadvantaged
# 593       985  Achievement School District                English Learners
# 594       985  Achievement School District      Students with Disabilities
#
#      Valid Tests Participation Rate Average English Score Average Math Score  \
# 0            527                100                    19               18.7
# 1             17                100                    18               17.8
# 2            189                 99                  17.1               17.2
# 3              3                  *                     *                  *
# 4             76                100                  12.5               15.5
# ..           ...                ...                   ...                ...
# 590          294                 83                  13.4               15.4
# 591          292                 83                  13.4               15.4
# 592          244                 83                  13.2               15.2
# 593            7                  *                     *                  *
# 594           40                 67                    11               14.6
#
#     Average Reading Score Average Science Score Average Composite Score  \
# 0                    19.9                  19.6                    19.5
# 1                    17.5                  18.3                    17.9
# 2                    18.6                  18.1                    17.9
# 3                       *                     *                       *
# 4                    14.5                  15.1                    14.6
# ..                    ...                   ...                     ...
# 590                  14.8                    15                    14.8
# 591                  14.9                    15                    14.8
# 592                  14.6                  14.7                    14.6
# 593                     *                     *                       *
# 594                    13                  13.1                      13
#
#     Number Scoring 21 or Higher Percent Scoring 21 or Higher  \
# 0                           198                         37.6
# 1                             5                         29.4
# 2                            43                         22.8
# 3                             *                            *
# 4                             2                          2.6
# ..                          ...                          ...
# 590                          14                          4.8
# 591                          14                          4.8
# 592                           9                          3.7
# 593                           *                            *
# 594                          **                           **
#
#     Number Scoring Below 19 Percent Scoring Below 19
# 0                       254                     48.2
# 1                        10                     58.8
# 2                       118                     62.4
# 3                         *                        *
# 4                        71                     93.4
# ..                      ...                      ...
# 590                     261                     88.8
# 591                     259                     88.7
# 592                     221                     90.6
# 593                       *                        *
# 594                      **                       **
#
# [595 rows x 14 columns]

# %%
df2019 = df7[df7['District Name'] == 'Davidson County']
df2019 = df2019[df2019['Subgroup'] == 'All Students']
df2019 = df2019[['Average Composite Score']]

# %%
df2019
# Out:
#     Average Composite Score
# 127                    18.5
