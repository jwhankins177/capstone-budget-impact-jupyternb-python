# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel(r'C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\data_2010_District-Attendance-and-Graduation.xlsx',index_col = 0)

# %%
df
# Out:
#      Unnamed: 1             Unnamed: 2          K-8 Attendance  \
# year   district          district_name  K-8 Attendance Rate(%)
# 2010         10        Anderson County                    94.9
# 2010         11                Clinton                    95.1
# 2010         12              Oak Ridge                    95.1
# 2010         20         Bedford County                    95.2
# ...         ...                    ...                     ...
# 2010        940      Williamson County                    96.4
# 2010        941           Franklin SSD                    96.7
# 2010        950          Wilson County                    95.2
# 2010        951                Lebanon                       -
# 2010        963  Tenn School For Blind                       -
#
#                  Unnamed: 4                  Unnamed: 5  \
# year  K-8 Promotion Rate(%)  State Goal Attendance Rate
# 2010                   99.6                          93
# ...
