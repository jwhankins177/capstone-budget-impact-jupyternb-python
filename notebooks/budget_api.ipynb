# %%
import requests
import matplotlib.pyplot as plt
import urllib

# %%
endpoint = 'https://data.tn.gov/api/action/datastore_search?resource_id=8346049d-4ac9-4ed2-8cdf-6f8621094f36&'

response = requests.get(endpoint)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"help": "https://data.tn.gov/api/3/action/help_show?name=datastore_search", "success": true, "result": {"resource_id": "8346049d-4ac9-4ed2-8cdf-6f8621094f36", "fields": [{"type": "int4", "id": "_id"}, {"type": "numeric", "id": "DocFY"}, {"type": "numeric", "id": "FiscalYear"}, {"type": "numeric", "id": "FunctionalGroupCode"}, {"type": "text", "id": "FunctionalGroupName"}, {"type": "numeric", "id": "DeptCode"}, {"type": "text", "id": "DeptName"}, {"type": "numeric", "id": "AllotCode"}, {"type": "text", "id": "AllotName"}, {"type": "numeric", "id": "FundNbr"}, {"type": "text", "id": "Fund"}, {"type": "text", "id": "Variable"}, {"type": "text", "id": "Type"}, {"type": "text", "id": "Category"}, {"type": "numeric", "id": "Amount"}], "records": [{"Category": "Full-Time", "FundNbr": "11", "Type": "Positions", "Amount": "33", "Variable": "Estimated", "FunctionalGroupCode": "3", "Fund": "General Fund", "DeptCode": "31602", "DocFY": "2012", "AllotCode": "31602", "AllotName": "Commission on 
# ...

# %%
res = response.json()
res
# Out:
# {'help': 'https://data.tn.gov/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'resource_id': '8346049d-4ac9-4ed2-8cdf-6f8621094f36',
#   'fields': [{'type': 'int4', 'id': '_id'},
#    {'type': 'numeric', 'id': 'DocFY'},
#    {'type': 'numeric', 'id': 'FiscalYear'},
#    {'type': 'numeric', 'id': 'FunctionalGroupCode'},
#    {'type': 'text', 'id': 'FunctionalGroupName'},
#    {'type': 'numeric', 'id': 'DeptCode'},
#    {'type': 'text', 'id': 'DeptName'},
#    {'type': 'numeric', 'id': 'AllotCode'},
#    {'type': 'text', 'id': 'AllotName'},
#    {'type': 'numeric', 'id': 'FundNbr'},
#    {'type': 'text', 'id': 'Fund'},
#    {'type': 'text', 'id': 'Variable'},
#    {'type': 'text', 'id': 'Type'},
#    {'type': 'text', 'id': 'Category'},
#    {'type': 'numeric', 'id': 'Amount'}],
#   'records': [{'Category': 'Full-Time',
#     'FundNbr': '11',
#     'Type': 'Positions',
#     'Amount': '33',
#     'Variable': 'Estimated',
# ...
