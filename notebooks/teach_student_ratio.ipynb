# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df2010 = pd.read_excel(r'C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\capstone2\teacher and admin count\data_2010_district_profile.xlsx')
df2011 = pd.read_excel(r'C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\capstone2\teacher and admin count\data_2011_district_profile.xlsx')
df2012 = pd.read_excel(r'C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\capstone2\teacher and admin count\data_2012_district_profile.xlsx')
df2013 = pd.read_excel(r'C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\capstone2\teacher and admin count\data_2013_district_profile.xlsx')
df2014 = pd.read_excel(r'C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\capstone2\teacher and admin count\data_2014_district_profile.xlsx')
df2015 = pd.read_excel(r'C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\capstone2\teacher and admin count\data_2015_district_profile.xlsx')
df2016 = pd.read_excel(r'C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\capstone2\teacher and admin count\data_2015-16_district_profile.xlsx')
df2017 = pd.read_excel(r'C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\capstone2\teacher and admin count\data_2016-17_district_profile.xlsx')
df2018 = pd.read_excel(r'C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\capstone2\teacher and admin count\district_profile_2017-18.xlsx')
df2019 = pd.read_excel(r'C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\capstone2\teacher and admin count\districtprofile201819 (1).xlsx')

# %%
df2013
# Out:
#    YEAR  DISTRICT    DISTRICT NAME Grades served  Number of schools  \
# 0  2013       190  Davidson County         PK-12                158
#
#    Administrators  Teachers  Average Daily Membership  Total  White  ...  \
# 0             757      5576                     76249  81134  25810  ...
#
#    Title I  Title I PCT  Per Pupil Expenditures per ADA  Local Funding PCT  \
# 0      NaN          NaN                            9293               40.1
#
#    Federal Funding PCT  State Funding PCT  \
# 0                 11.3               48.7
#
#    State Per Pupil Expenditures per ADA  State Local Funding PCT  \
# 0                                  9293                     40.1
#
#    State Federal Funding PCT  State State Funding PCT
# 0                       11.3                     48.7
#
# [1 rows x 54 columns]

# %%
df = [df2010,df2011,df2012,df2013,df2014,df2015,df2016,df2017,df2018,df2019]

# %%
result = pd.concat(df)

# %%
result
# Out:
#      year  district    district_name Grades served  Number of schools  \
# 0  2010.0     190.0  Davidson County         PK-12              133.0
# 0  2011.0     190.0  Davidson County         PK-12              137.0
# 0  2012.0     190.0  Davidson County         PK-12              143.0
# 0     NaN       NaN              NaN         PK-12              158.0
# 0  2014.0     190.0  Davidson County           NaN                NaN
# 0     NaN       NaN              NaN           NaN                NaN
# 0     NaN       NaN              NaN           NaN                NaN
# 0     NaN       NaN              NaN           NaN                NaN
# 0     NaN       NaN              NaN           NaN                NaN
# 0     NaN       NaN              NaN           NaN                NaN
#
#    Administrators  Teachers  Average Daily Membership    Total    White  ...  \
# 0           562.0    5064.0                   71708.0  75100.0  24554.0  ...
# ...
