# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel(r"C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\davidson_budget_2011_2021.xlsx")

# %%
df.head(20)
# Out:
#    CFG Budget Data Reconciliation    Unnamed: 1    Unnamed: 2    Unnamed: 3  \
# 0                             NaN           NaN           NaN           NaN
# 1                             NaN  2.011000e+03  2.012000e+03  2.013000e+03
# 2                             NaN           NaN           NaN           NaN
# 3                        CFG Data           NaN           NaN           NaN
# 4                         Payroll  2.844606e+09  2.851555e+09  2.908193e+09
# 5                     Operational  2.915524e+10  2.907775e+10  2.942078e+10
# 6              Total Expenditures  3.199984e+10  3.192931e+10  3.232898e+10
# 7                             NaN           NaN           NaN           NaN
# 8            State Appropriations  1.291803e+10  1.363289e+10  1.422184e+10
# 9                 Federal Revenue  1.392998e+10  1.312466e+10  1.306982e+10
# 10                  Other Revenue  3.506904e+09  3.257820e+09  3.089804e+09
# ...

# %%
df.tail(20)
# Out:
#    CFG Budget Data Reconciliation  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 41                            NaN         NaN         NaN         NaN
# 42                            NaN         NaN         NaN         NaN
# 43                       Variance         NaN         NaN         NaN
# 44                        Payroll         0.0         0.0         0.0
# 45                    Operational         0.0         0.0         0.0
# 46             Total Expenditures         0.0         0.0         0.0
# 47                            NaN         NaN         NaN         NaN
# 48           State Appropriations         0.0         0.0         0.0
# 49                Federal Revenue         0.0         0.0         0.0
# 50                  Other Revenue         0.0         0.0         0.0
# 51               Tuition and Fees         0.0         0.0         0.0
# 52                          Bonds         0.0         0.0         0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CFG Budget Data Reconciliation  45 non-null     object
#  1   Unnamed: 1                      43 non-null     float64
#  2   Unnamed: 2                      43 non-null     float64
#  3   Unnamed: 3                      43 non-null     float64
#  4   Unnamed: 4                      43 non-null     float64
#  5   Unnamed: 5                      43 non-null     float64
#  6   Unnamed: 6                      43 non-null     float64
#  7   Unnamed: 7                      43 non-null     float64
#  8   Unnamed: 8                      43 non-null     float64
#  9   Unnamed: 9                      43 non-null     float64
#  10  Unnamed: 10                     43 non-null     float64
#  11  Unnamed: 11                     43 non-null     float64
# ...
