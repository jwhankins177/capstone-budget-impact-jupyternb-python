# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\jhank\Desktop\DA7\Projects\budget-impact-jupyternb-python\data\Metro_Budget_to_Actual_Expenses__FY2010_-_Present_.csv")

# %%
df.head(5)
# Out:
#     Fund Fund Description  Department Department Description  Business Unit  \
# 0  10101      GSD General         1.0         Administrative      1101104.0
# 1  10101      GSD General         1.0         Administrative      1101107.0
# 2  10101      GSD General         1.0         Administrative      1101109.0
# 3  10101      GSD General         1.0         Administrative      1101109.0
# 4  10101      GSD General         1.0         Administrative      1101109.0
#
#      Business Unit Description  Object Account   Object Account Description  \
# 0      ADM County Retire Match        531702.0  Transfer Guaranteed Pension
# 1  ADM Cnty Teach Retire Match        531702.0  Transfer Guaranteed Pension
# 2   ADM Health Insurance Match        501174.0        Employer Group Health
# 3   ADM Health Insurance Match        501175.0        Employer Dental Group
# 4   ADM Health Insurance Match        501176.0          Employer Group Life
#
# ...

# %%
df.tail(20)
# Out:
#               Fund      Fund Description  Department Department Description  \
# 30813        35131  MNPS General Purpose        80.0                   MNPS
# 30814        35131  MNPS General Purpose        80.0                   MNPS
# 30815        35131  MNPS General Purpose        80.0                   MNPS
# 30816        35131  MNPS General Purpose        80.0                   MNPS
# 30817        35131  MNPS General Purpose        80.0                   MNPS
# 30818        35131  MNPS General Purpose        80.0                   MNPS
# 30819        35131  MNPS General Purpose        80.0                   MNPS
# 30820        35131  MNPS General Purpose        80.0                   MNPS
# 30821        35131  MNPS General Purpose        80.0                   MNPS
# 30822        35131  MNPS General Purpose        80.0                   MNPS
# 30823        35131  MNPS General Purpose        80.0                   MNPS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30833 entries, 0 to 30832
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Fund                        30833 non-null  object
#  1   Fund Description            30832 non-null  object
#  2   Department                  30832 non-null  float64
#  3   Department Description      30832 non-null  object
#  4   Business Unit               30832 non-null  float64
#  5   Business Unit Description   30832 non-null  object
#  6   Object Account              30832 non-null  float64
#  7   Object Account Description  30832 non-null  object
#  8   FY2010 Budgeted Expenses    30833 non-null  float64
#  9   FY2010 Actual Expenses      30833 non-null  float64
#  10  FY2011 Budgeted Expenses    30833 non-null  float64
#  11  FY2011 Actual Expenses      30833 non-null  float64
#  12  FY2012 Budgeted Expenses    30833 non-null  float64
# ...

# %%
df['Department'].nunique()
# Out:
# 52

# %%
dep_list = df['Department Description'].unique()

# %%
dep_list
# Out:
# array(['Administrative', 'Sheriff', 'Metropolitan Council',
#        'Metropolitan Clerk', "Mayor's Office", 'Election Commission',
#        'Law', 'Planning Commission', 'Human Resources',
#        'Register of Deeds', 'General Services', 'Historical Commission',
#        'Information Technology Service', 'Finance',
#        'Assessor of Property', 'Trustee', 'County Clerk',
#        'District Attorney', 'X-Medical Examiner', 'Public Defender',
#        'Juvenile Court Clerk', 'Circuit Court Clerk',
#        'Criminal Court Clerk', 'Clerk and Master - Chancery',
#        'Juvenile Court', 'Police', 'General Sessions Court',
#        'State Trial Courts', 'Justice Integration Services', 'Fire',
#        'Codes Administration', 'Beer Board', 'Social Services',
#        'Agricultural Extension', 'Soil and Water Conservation', 'Health',
#        'Public Library', 'Parks', 'Arts Commission', 'Public Works',
#        'MNPS', 'Human Relations Commission', 'X-Transportation Licensing',
# ...

# %% [markdown]
# Look at library only.

# %%
library = df[df["Department Description"] == 'Public Library']

# %%
library
# Out:
#         Fund Fund Description  Department Department Description  \
# 14037  10101      GSD General        39.0         Public Library
# 14277  10101      GSD General        39.0         Public Library
# 14314  10101      GSD General        39.0         Public Library
# 14315  10101      GSD General        39.0         Public Library
# 14316  10101      GSD General        39.0         Public Library
# ...      ...              ...         ...                    ...
# 16193  10101      GSD General        39.0         Public Library
# 16194  10101      GSD General        39.0         Public Library
# 16195  10101      GSD General        39.0         Public Library
# 16196  10101      GSD General        39.0         Public Library
# 16197  10101      GSD General        39.0         Public Library
#
#        Business Unit       Business Unit Description  Object Account  \
# 14037     39103335.0               LIB Goodletsville        502883.0
# ...

# %% [markdown]
# Business Unit Description's that start with x- seems to have be stopped being used. Need to confirm that.

# %%
library['Business Unit Description'].nunique()
# Out:
# 66

# %%
library['Business Unit Description'].unique()
# Out:
# array(['LIB Goodletsville', 'LIB Administrative Support',
#        'LIB Public Relations', 'LIB Inglewood', 'LIB Technical Services',
#        'LIB Conference Center', 'LIB Interlibrary Loan',
#        'LIB Special Collections', 'LIB Community Engagement',
#        'LIB Limitless Libraries', 'LIB Operation and Maintenance',
#        'LIB Production Services', 'LIB BW Circulation',
#        "LIB BW Children's Services", 'LIB Reference Services',
#        'LIB Teen Services', 'LIB Digital Inclusion',
#        'LIB Performing Artists', 'LIB Public Technology Program',
#        'LIB Studio NPL', 'LIB Hermitage Branch', 'LIB Edmondson Branch',
#        'LIB East', 'LIB Bellevue', 'LIB Bordeaux', 'LIB North Library',
#        'LIB Donelson', 'LIB Edgehill', 'LIB Green Hills',
#        'LIB Hadley Park', 'LIB Looby', 'LIB Madison', 'LIB Old Hickory',
#        'LIB Pruitt', 'LIB Richland Park', 'LIB Southeast',
#        'LIB Thompson Lane', 'LIB Archives', 'LIB Watkins Park',
# ...

# %%
library.describe
# Out:
# <bound method NDFrame.describe of         Fund Fund Description  Department Department Description  \
# 14037  10101      GSD General        39.0         Public Library
# 14277  10101      GSD General        39.0         Public Library
# 14314  10101      GSD General        39.0         Public Library
# 14315  10101      GSD General        39.0         Public Library
# 14316  10101      GSD General        39.0         Public Library
# ...      ...              ...         ...                    ...
# 16193  10101      GSD General        39.0         Public Library
# 16194  10101      GSD General        39.0         Public Library
# 16195  10101      GSD General        39.0         Public Library
# 16196  10101      GSD General        39.0         Public Library
# 16197  10101      GSD General        39.0         Public Library
#
#        Business Unit       Business Unit Description  Object Account  \
# 14037     39103335.0               LIB Goodletsville        502883.0
# ...

# %%
gb_library = library.groupby(['Department Description'])

# %%
gb_library.head()
# Out:
#         Fund Fund Description  Department Department Description  \
# 14037  10101      GSD General        39.0         Public Library
# 14277  10101      GSD General        39.0         Public Library
# 14314  10101      GSD General        39.0         Public Library
# 14315  10101      GSD General        39.0         Public Library
# 14316  10101      GSD General        39.0         Public Library
#
#        Business Unit   Business Unit Description  Object Account  \
# 14037     39103335.0           LIB Goodletsville        502883.0
# 14277     39101010.0  LIB Administrative Support        502359.0
# 14314     39101010.0  LIB Administrative Support        501174.0
# 14315     39101010.0  LIB Administrative Support        501175.0
# 14316     39101010.0  LIB Administrative Support        501176.0
#
#       Object Account Description  FY2010 Budgeted Expenses  \
# 14037               Registration                       0.0
# 14277     Devlop/Framing/Artwork                       0.0
# ...
